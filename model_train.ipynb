# %%
import os
import glob
import torch
import time
import SimpleITK as sitk
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader, random_split
from monai.transforms import (
    Compose, LoadImaged, EnsureChannelFirstd, EnsureTyped, Orientationd, Spacingd,
    RandSpatialCropd, RandFlipd, NormalizeIntensityd, RandScaleIntensityd, RandShiftIntensityd,
    Activations, AsDiscrete, MapTransform, SpatialPadd
)
from monai.networks.nets import SwinUNETR
from monai.metrics import DiceMetric
from monai.losses import DiceLoss
from monai.inferers import sliding_window_inference
from torch.nn import functional as F

# %%
class CustomCTDataset(Dataset):
    def __init__(self, image_dir, label_dir, transform=None):
        self.image_dir = image_dir
        self.label_dir = label_dir
        self.transform = transform
        self.data = self._load_data()

    def _load_data(self):
        """加载CT图像和对应的标签数据"""
        data = []
        # 获取所有患者ID
        patient_ids = set()
        for filename in os.listdir(self.image_dir):
            if filename.endswith(".nii.gz"):
                patient_id = filename.split(".nii.gz")[0]
                patient_ids.add(patient_id)
        
        
        # 匹配图像和标签
        for patient_id in patient_ids:
            image_path = os.path.join(self.image_dir, f"{patient_id}.nii.gz")
            label_path = os.path.join(self.label_dir, f"{patient_id}.nii.gz")
            
            if os.path.exists(image_path) and os.path.exists(label_path):
                data.append({
                    "image": image_path,
                    "label": label_path
                })
            else:
                print(f"Warning: Missing data for patient {patient_id}")
                print(image_path, label_path)
                
        return data

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        data = self.data[index]
        if self.transform:
            data = self.transform(data)
        return data

# %%
CustomCTDataset("/workspace/Task04_Hippocampus/imagesTr", "/workspace/Task04_Hippocampus/labelsTr")

# %%
class ConvertToMultiChannel5Classesd(MapTransform):
    """将5亚型标签转换为多通道格式"""
    def __call__(self, data):
        d = dict(data)
        for key in self.keys:
            # 为每个亚型创建一个通道
            result = [
                d[key] == 1,  # 亚型1
                d[key] == 2,  # 亚型2
                d[key] == 3,  # 亚型3
                d[key] == 4,  # 亚型4
                d[key] == 5   # 亚型5
            ]
            d[key] = torch.stack(result, axis=0).float()
        return d

# %%
# 定义数据变换
train_transform = Compose(
    [
        LoadImaged(keys=["image", "label"]),
        EnsureChannelFirstd(keys="image"),  # 单模态数据，添加通道维度
        EnsureTyped(keys=["image", "label"]),
        ConvertToMultiChannel5Classesd(keys="label"),  # 转换为5通道标签
        SpatialPadd(
            keys=["image", "label"],
            spatial_size=(64, 64, 64),  # (D, H, W) — divisible by 32
            method="end",
        ),
        #rientationd(keys=["image", "label"], axcodes="RAS"),  # 调整方向
        #pacingd(
        #   keys=["image", "label"],
        #   pixdim=(1.0, 1.0, 1.0),  # 重采样到1mm×1mm×1mm
        #   mode=("bilinear", "nearest"),  # 图像双线性插值，标签最近邻插值
        #,
        #andSpatialCropd(keys=["image", "label"], roi_size=[192, 192, 192], random_size=False),  # 随机裁剪
        RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=0),  # 随机翻转
        RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=1),
        RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=2),
        NormalizeIntensityd(keys="image", nonzero=True, channel_wise=True),  # 归一化
        RandScaleIntensityd(keys="image", factors=0.1, prob=1.0),  # 随机缩放强度
        RandShiftIntensityd(keys="image", offsets=0.1, prob=1.0),  # 随机偏移强度
    ]
)

val_transform = Compose(
    [
        LoadImaged(keys=["image", "label"]),
        EnsureChannelFirstd(keys="image"),
        EnsureTyped(keys=["image", "label"]),
        ConvertToMultiChannel5Classesd(keys="label"),
        SpatialPadd(
            keys=["image", "label"],
            spatial_size=(64, 64, 64),  # (D, H, W) — divisible by 32
            method="end",
        ),
        #rientationd(keys=["image", "label"], axcodes="RAS"),
        #pacingd(
        #   keys=["image", "label"],
        #   pixdim=(1.0, 1.0, 1.0),
        #   mode=("bilinear", "nearest"),
        #,
        NormalizeIntensityd(keys="image", nonzero=True, channel_wise=True),
    ]
)

# %%
# 数据路径
image_dir = "/workspace/Task04_Hippocampus/imagesTr"
label_dir = "/workspace/Task04_Hippocampus/labelsTr"

# 创建数据集
full_dataset = CustomCTDataset(
    image_dir=image_dir,
    label_dir=label_dir,
    transform=None
)

# 划分训练集和验证集
train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

# 应用变换
train_dataset.dataset.transform = train_transform
val_dataset.dataset.transform = val_transform

# 创建数据加载器
train_loader = DataLoader(train_dataset, batch_size=1, shuffle=True, num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=1, shuffle=False, num_workers=4)

# %%
sample = train_dataset[0]
print(sample["image"].shape)
# Out:
# torch.Size([1, 64, 64, 64])

# %%
batch = next(iter(train_loader))
print(batch["image"].shape)
# Out:
# torch.Size([1, 1, 64, 64, 64])

# %%
# 模型配置
max_epochs = 50
val_interval = 1
VAL_AMP = True

# 设备配置
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 初始化模型
model = SwinUNETR(
    #img_size=(192, 192, 192),  # 输入图像大小
    in_channels=1,             # 单模态CT
    out_channels=5,            # 5个亚型
    feature_size=48,
    use_checkpoint=True
).to(device)

# 损失函数和优化器
loss_function = DiceLoss(
    smooth_nr=0, 
    smooth_dr=1e-5, 
    squared_pred=True, 
    to_onehot_y=False, 
    sigmoid=True
)
optimizer = torch.optim.Adam(model.parameters(), 1e-4, weight_decay=1e-5)
lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=max_epochs)

# 评估指标
dice_metric = DiceMetric(include_background=True, reduction="mean")
dice_metric_batch = DiceMetric(include_background=True, reduction="mean_batch")

# 后处理
post_trans = Compose([Activations(sigmoid=True), AsDiscrete(threshold=0.5)])


# 推理函数
def inference(input):
    def _compute(input):
        return sliding_window_inference(
            inputs=input,
            roi_size=(64, 64, 32),
            sw_batch_size=1,
            predictor=model,
            overlap=0.5,
        )

    if VAL_AMP:
        with torch.cuda.amp.autocast():
            return _compute(input)
    else:
        return _compute(input)


# 训练过程
best_metric = -1
best_metric_epoch = -1
epoch_loss_values = []
metric_values = []
# 5个亚型的指标存储
metric_values_class1 = []
metric_values_class2 = []
metric_values_class3 = []
metric_values_class4 = []
metric_values_class5 = []

total_start = time.time()

# 创建模型保存目录
os.makedirs("ct_models", exist_ok=True)

for epoch in range(max_epochs):
    epoch_start = time.time()
    print("-" * 10)
    print(f"epoch {epoch + 1}/{max_epochs}")
    model.train()
    epoch_loss = 0
    step = 0

    for batch_data in train_loader:
        step_start = time.time()
        step += 1
        inputs = batch_data["image"].to(device)
        labels = batch_data["label"].to(device)

        # 根据需要调整pad大小以匹配模型输入
        pad_sizes = (0, 0, 0, 0, 0, 0)  # 可根据实际数据尺寸调整
        # if any(pad_sizes):
        #     inputs = F.pad(inputs, pad_sizes, mode="constant", value=0).to(device)

        # 前向传播
        outputs = model(inputs)
        
        # 如果有padding，裁剪回原始大小
        # if any(pad_sizes):
        #     outputs = outputs[:, :, pad_sizes[0]:-pad_sizes[1], 
        #                      pad_sizes[2]:-pad_sizes[3], 
        #                      pad_sizes[4]:-pad_sizes[5]]

        # 计算损失
        loss = loss_function(outputs, labels)
        epoch_loss += loss.item()

        # 反向传播和优化
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # print(
        #     f"{step}/{len(train_dataset) // train_loader.batch_size}"
        #     f", train_loss: {loss.item():.4f}"
        #     f", step time: {(time.time() - step_start):.4f}"
        # )

    # 学习率调整
    lr_scheduler.step()
    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")

    # 验证过程
    if (epoch + 1) % val_interval == 0:
        model.eval()
        with torch.no_grad():
            for val_data in val_loader:
                val_inputs = val_data["image"].to(device)
                val_labels = val_data["label"].to(device)

                # 处理padding
                # if any(pad_sizes):
                #     val_inputs = F.pad(val_inputs, pad_sizes, mode="constant", value=0).to(device)

                # 推理
                val_outputs = inference(val_inputs)
                
                # 裁剪回原始大小
                if any(pad_sizes):
                    val_outputs = val_outputs[:, :, pad_sizes[0]:-pad_sizes[1], 
                                            pad_sizes[2]:-pad_sizes[3], 
                                            pad_sizes[4]:-pad_sizes[5]]

                # 后处理
                val_outputs = [post_trans(i) for i in val_outputs]
                
                # 计算指标
                dice_metric(y_pred=val_outputs, y=val_labels)
                dice_metric_batch(y_pred=val_outputs, y=val_labels)

            # 聚合指标
            metric = dice_metric.aggregate().item()
            metric_values.append(metric)
            metric_batch = dice_metric_batch.aggregate()

            # 每个类别的Dice
            metric_class1 = metric_batch[0].item()
            metric_class2 = metric_batch[1].item()
            metric_class3 = metric_batch[2].item()
            metric_class4 = metric_batch[3].item()
            metric_class5 = metric_batch[4].item()

            metric_values_class1.append(metric_class1)
            metric_values_class2.append(metric_class2)
            metric_values_class3.append(metric_class3)
            metric_values_class4.append(metric_class4)
            metric_values_class5.append(metric_class5)

            # 重置指标
            dice_metric.reset()
            dice_metric_batch.reset()

            # 保存最佳模型
            current_time = time.localtime()
            formatted_time = time.strftime("%Y-%m-%d %H:%M:%S", current_time)
            if metric > best_metric:
                best_metric = metric
                best_metric_epoch = epoch + 1
                torch.save(
                    model.state_dict(),
                    os.path.join("ct_models", f"best_model_{epoch + 1}.pth"),
                )
                print("Saved new best metric model")

            # 打印和记录指标
            print(
                f"current epoch: {epoch + 1} current mean dice: {metric:.4f}"
                f"\nclass1: {metric_class1:.4f} class2: {metric_class2:.4f} "
                f"class3: {metric_class3:.4f} class4: {metric_class4:.4f} class5: {metric_class5:.4f}"
                f"\nbest mean dice: {best_metric:.4f} at epoch: {best_metric_epoch}"
            )

            # 写入日志文件
            with open('ct_training_log.txt', 'a+') as f:
                f.write(
                    f"epoch: {epoch + 1} time: {formatted_time}\n"
                    f"mean dice: {metric:.4f}\n"
                    f"class1: {metric_class1:.4f} class2: {metric_class2:.4f} "
                    f"class3: {metric_class3:.4f} class4: {metric_class4:.4f} class5: {metric_class5:.4f}\n"
                    f"best mean dice: {best_metric:.4f} at epoch: {best_metric_epoch}\n\n"
                )

    print(f"epoch {epoch + 1} time: {(time.time() - epoch_start):.4f}")

total_time = time.time() - total_start
print(f"Training completed! Best metric: {best_metric:.4f} at epoch {best_metric_epoch}, total time: {total_time:.4f}s")

# 保存最终结果
with open('ct_training_final.txt', 'w') as f:
    f.write(f"Training completed! Best mean dice: {best_metric:.4f} at epoch {best_metric_epoch}\n")
    f.write(f"Total training time: {total_time:.4f} seconds\n")
    f.write(f"Class 1 best dice: {max(metric_values_class1):.4f}\n")
    f.write(f"Class 2 best dice: {max(metric_values_class2):.4f}\n")
    f.write(f"Class 3 best dice: {max(metric_values_class3):.4f}\n")
    f.write(f"Class 4 best dice: {max(metric_values_class4):.4f}\n")
    f.write(f"Class 5 best dice: {max(metric_values_class5):.4f}\n")
# Out:
# ----------
# epoch 1/50
# epoch 1 average loss: 0.9782
# /tmp/ipykernel_3121/2400480935.py:49: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /venv/main/lib/python3.12/site-packages/monai/inferers/utils.py:370: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:345.)
#   out[idx_zm] += p
# Saved new best metric model
# current epoch: 1 current mean dice: 0.1094
# class1: 0.0640 class2: 0.1548 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.1094 at epoch: 1
# epoch 1 time: 6.1932
# ----------
# epoch 2/50
# epoch 2 average loss: 0.9553
# Saved new best metric model
# current epoch: 2 current mean dice: 0.1650
# class1: 0.0456 class2: 0.2845 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.1650 at epoch: 2
# epoch 2 time: 6.1523
# ----------
# epoch 3/50
# epoch 3 average loss: 0.9339
# Saved new best metric model
# current epoch: 3 current mean dice: 0.2875
# class1: 0.0455 class2: 0.5295 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.2875 at epoch: 3
# epoch 3 time: 6.1318
# ----------
# epoch 4/50
# epoch 4 average loss: 0.9157
# Saved new best metric model
# current epoch: 4 current mean dice: 0.3407
# class1: 0.0445 class2: 0.6369 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.3407 at epoch: 4
# epoch 4 time: 6.1392
# ----------
# epoch 5/50
# epoch 5 average loss: 0.9000
# Saved new best metric model
# current epoch: 5 current mean dice: 0.3585
# class1: 0.0440 class2: 0.6730 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.3585 at epoch: 5
# epoch 5 time: 6.1513
# ----------
# epoch 6/50
# epoch 6 average loss: 0.8877
# Saved new best metric model
# current epoch: 6 current mean dice: 0.3624
# class1: 0.0438 class2: 0.6809 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.3624 at epoch: 6
# epoch 6 time: 6.1519
# ----------
# epoch 7/50
# epoch 7 average loss: 0.8786
# Saved new best metric model
# current epoch: 7 current mean dice: 0.3867
# class1: 0.0432 class2: 0.7301 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.3867 at epoch: 7
# epoch 7 time: 6.1713
# ----------
# epoch 8/50
# epoch 8 average loss: 0.8703
# Saved new best metric model
# current epoch: 8 current mean dice: 0.3914
# class1: 0.0430 class2: 0.7398 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.3914 at epoch: 8
# epoch 8 time: 6.1374
# ----------
# epoch 9/50
# epoch 9 average loss: 0.8632
# Saved new best metric model
# current epoch: 9 current mean dice: 0.4095
# class1: 0.0438 class2: 0.7753 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.4095 at epoch: 9
# epoch 9 time: 6.1398
# ----------
# epoch 10/50
# epoch 10 average loss: 0.8572
# current epoch: 10 current mean dice: 0.4085
# class1: 0.0443 class2: 0.7726 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.4095 at epoch: 9
# epoch 10 time: 6.1046
# ----------
# epoch 11/50
# epoch 11 average loss: 0.8518
# Saved new best metric model
# current epoch: 11 current mean dice: 0.4113
# class1: 0.0449 class2: 0.7777 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.4113 at epoch: 11
# epoch 11 time: 6.1466
# ----------
# epoch 12/50
# epoch 12 average loss: 0.8469
# current epoch: 12 current mean dice: 0.3995
# class1: 0.0456 class2: 0.7535 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.4113 at epoch: 11
# epoch 12 time: 5.8840
# ----------
# epoch 13/50
# epoch 13 average loss: 0.8426
# current epoch: 13 current mean dice: 0.4099
# class1: 0.0460 class2: 0.7738 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.4113 at epoch: 11
# epoch 13 time: 5.8744
# ----------
# epoch 14/50
# epoch 14 average loss: 0.8378
# current epoch: 14 current mean dice: 0.4101
# class1: 0.0472 class2: 0.7730 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.4113 at epoch: 11
# epoch 14 time: 5.8507
# ----------
# epoch 15/50
# epoch 15 average loss: 0.8328
# Saved new best metric model
# current epoch: 15 current mean dice: 0.4151
# class1: 0.0499 class2: 0.7803 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.4151 at epoch: 15
# epoch 15 time: 6.1260
# ----------
# epoch 16/50
# epoch 16 average loss: 0.8279
# Saved new best metric model
# current epoch: 16 current mean dice: 0.4316
# class1: 0.0852 class2: 0.7779 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.4316 at epoch: 16
# epoch 16 time: 6.2644
# ----------
# epoch 17/50
# epoch 17 average loss: 0.8226
# Saved new best metric model
# current epoch: 17 current mean dice: 0.5345
# class1: 0.2772 class2: 0.7917 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.5345 at epoch: 17
# epoch 17 time: 6.2132
# ----------
# epoch 18/50
# epoch 18 average loss: 0.8173
# Saved new best metric model
# current epoch: 18 current mean dice: 0.6862
# class1: 0.5726 class2: 0.7998 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.6862 at epoch: 18
# epoch 18 time: 6.4400
# ----------
# epoch 19/50
# epoch 19 average loss: 0.8076
# Saved new best metric model
# current epoch: 19 current mean dice: 0.7549
# class1: 0.7026 class2: 0.8072 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.7549 at epoch: 19
# epoch 19 time: 6.3289
# ----------
# epoch 20/50
# epoch 20 average loss: 0.7951
# Saved new best metric model
# current epoch: 20 current mean dice: 0.7595
# class1: 0.7098 class2: 0.8091 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.7595 at epoch: 20
# epoch 20 time: 6.2698
# ----------
# epoch 21/50
# epoch 21 average loss: 0.7803
# Saved new best metric model
# current epoch: 21 current mean dice: 0.8096
# class1: 0.8080 class2: 0.8111 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8096 at epoch: 21
# epoch 21 time: 6.2912
# ----------
# epoch 22/50
# epoch 22 average loss: 0.7649
# current epoch: 22 current mean dice: 0.8000
# class1: 0.8161 class2: 0.7840 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8096 at epoch: 21
# epoch 22 time: 6.0063
# ----------
# epoch 23/50
# epoch 23 average loss: 0.7505
# Saved new best metric model
# current epoch: 23 current mean dice: 0.8257
# class1: 0.8345 class2: 0.8170 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8257 at epoch: 23
# epoch 23 time: 6.3181
# ----------
# epoch 24/50
# epoch 24 average loss: 0.7375
# current epoch: 24 current mean dice: 0.8186
# class1: 0.8194 class2: 0.8179 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8257 at epoch: 23
# epoch 24 time: 5.9642
# ----------
# epoch 25/50
# epoch 25 average loss: 0.7266
# current epoch: 25 current mean dice: 0.8181
# class1: 0.8291 class2: 0.8072 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8257 at epoch: 23
# epoch 25 time: 5.9657
# ----------
# epoch 26/50
# epoch 26 average loss: 0.7175
# Saved new best metric model
# current epoch: 26 current mean dice: 0.8284
# class1: 0.8477 class2: 0.8091 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8284 at epoch: 26
# epoch 26 time: 6.2824
# ----------
# epoch 27/50
# epoch 27 average loss: 0.7092
# Saved new best metric model
# current epoch: 27 current mean dice: 0.8342
# class1: 0.8485 class2: 0.8199 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8342 at epoch: 27
# epoch 27 time: 6.1973
# ----------
# epoch 28/50
# epoch 28 average loss: 0.7026
# current epoch: 28 current mean dice: 0.8280
# class1: 0.8415 class2: 0.8145 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8342 at epoch: 27
# epoch 28 time: 5.9327
# ----------
# epoch 29/50
# epoch 29 average loss: 0.6967
# current epoch: 29 current mean dice: 0.8317
# class1: 0.8455 class2: 0.8180 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8342 at epoch: 27
# epoch 29 time: 5.9276
# ----------
# epoch 30/50
# epoch 30 average loss: 0.6919
# current epoch: 30 current mean dice: 0.8294
# class1: 0.8415 class2: 0.8174 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8342 at epoch: 27
# epoch 30 time: 5.9141
# ----------
# epoch 31/50
# epoch 31 average loss: 0.6878
# current epoch: 31 current mean dice: 0.8301
# class1: 0.8428 class2: 0.8174 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8342 at epoch: 27
# epoch 31 time: 5.8848
# ----------
# epoch 32/50
# epoch 32 average loss: 0.6842
# current epoch: 32 current mean dice: 0.8311
# class1: 0.8439 class2: 0.8182 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8342 at epoch: 27
# epoch 32 time: 6.0958
# ----------
# epoch 33/50
# epoch 33 average loss: 0.6813
# current epoch: 33 current mean dice: 0.8341
# class1: 0.8492 class2: 0.8189 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8342 at epoch: 27
# epoch 33 time: 5.8909
# ----------
# epoch 34/50
# epoch 34 average loss: 0.6787
# current epoch: 34 current mean dice: 0.8312
# class1: 0.8452 class2: 0.8172 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8342 at epoch: 27
# epoch 34 time: 5.8971
# ----------
# epoch 35/50
# epoch 35 average loss: 0.6764
# current epoch: 35 current mean dice: 0.8309
# class1: 0.8424 class2: 0.8194 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8342 at epoch: 27
# epoch 35 time: 5.8852
# ----------
# epoch 36/50
# epoch 36 average loss: 0.6742
# current epoch: 36 current mean dice: 0.8314
# class1: 0.8463 class2: 0.8166 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8342 at epoch: 27
# epoch 36 time: 5.8814
# ----------
# epoch 37/50
# epoch 37 average loss: 0.6726
# current epoch: 37 current mean dice: 0.8238
# class1: 0.8368 class2: 0.8107 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8342 at epoch: 27
# epoch 37 time: 5.8980
# ----------
# epoch 38/50
# epoch 38 average loss: 0.6713
# current epoch: 38 current mean dice: 0.8306
# class1: 0.8422 class2: 0.8191 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8342 at epoch: 27
# epoch 38 time: 5.9109
# ----------
# epoch 39/50
# epoch 39 average loss: 0.6699
# current epoch: 39 current mean dice: 0.8292
# class1: 0.8424 class2: 0.8159 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8342 at epoch: 27
# epoch 39 time: 5.8981
# ----------
# epoch 40/50
# epoch 40 average loss: 0.6689
# current epoch: 40 current mean dice: 0.8292
# class1: 0.8422 class2: 0.8162 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8342 at epoch: 27
# epoch 40 time: 5.9052
# ----------
# epoch 41/50
# epoch 41 average loss: 0.6681
# current epoch: 41 current mean dice: 0.8284
# class1: 0.8420 class2: 0.8147 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8342 at epoch: 27
# epoch 41 time: 5.9008
# ----------
# epoch 42/50
# epoch 42 average loss: 0.6674
# current epoch: 42 current mean dice: 0.8285
# class1: 0.8423 class2: 0.8147 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8342 at epoch: 27
# epoch 42 time: 5.8878
# ----------
# epoch 43/50
# epoch 43 average loss: 0.6669
# current epoch: 43 current mean dice: 0.8281
# class1: 0.8418 class2: 0.8145 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8342 at epoch: 27
# epoch 43 time: 5.9426
# ----------
# epoch 44/50
# epoch 44 average loss: 0.6665
# current epoch: 44 current mean dice: 0.8281
# class1: 0.8418 class2: 0.8143 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8342 at epoch: 27
# epoch 44 time: 5.9872
# ----------
# epoch 45/50
# epoch 45 average loss: 0.6662
# current epoch: 45 current mean dice: 0.8282
# class1: 0.8418 class2: 0.8146 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8342 at epoch: 27
# epoch 45 time: 5.9265
# ----------
# epoch 46/50
# epoch 46 average loss: 0.6659
# current epoch: 46 current mean dice: 0.8281
# class1: 0.8416 class2: 0.8145 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8342 at epoch: 27
# epoch 46 time: 6.0382
# ----------
# epoch 47/50
# epoch 47 average loss: 0.6658
# current epoch: 47 current mean dice: 0.8280
# class1: 0.8415 class2: 0.8144 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8342 at epoch: 27
# epoch 47 time: 5.9796
# ----------
# epoch 48/50
# epoch 48 average loss: 0.6657
# current epoch: 48 current mean dice: 0.8280
# class1: 0.8414 class2: 0.8146 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8342 at epoch: 27
# epoch 48 time: 5.9784
# ----------
# epoch 49/50
# epoch 49 average loss: 0.6657
# current epoch: 49 current mean dice: 0.8280
# class1: 0.8414 class2: 0.8146 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8342 at epoch: 27
# epoch 49 time: 5.9852
# ----------
# epoch 50/50
# epoch 50 average loss: 0.6656
# current epoch: 50 current mean dice: 0.8281
# class1: 0.8415 class2: 0.8147 class3: 0.0000 class4: 0.0000 class5: 0.0000
# best mean dice: 0.8342 at epoch: 27
# epoch 50 time: 5.9172
# Training completed! Best metric: 0.8342 at epoch 27, total time: 302.3643s
